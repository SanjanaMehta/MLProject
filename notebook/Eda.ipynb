# %% [markdown]
# ## Student Performance Indicator
# ### Problem Statement:
# #### How performance is indicated by other factors
# #### Dataset has 8 columns and 1000 rows

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Sanjana\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
df=pd.read_csv(r"C:\Users\Sanjana\Downloads\my documents\projects\mlproject\mlproject-main\notebook\data\stud.csv")

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.displot(df['gender'])

# %% [markdown]
# race_ethnicity	parental_level_of_education	lunch	test_preparation_course

# %%
sns.countplot(df['race_ethnicity'])
# Out:
# C:\Users\Sanjana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race_ethnicity', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
order1=df['parental_level_of_education'].value_counts(ascending=True).index
sns.countplot(data=df,x='parental_level_of_education',order=order1)
# Out:
# <AxesSubplot:xlabel='parental_level_of_education', ylabel='count'>

# %%
sns.countplot(df['lunch'])
# Out:
# C:\Users\Sanjana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='lunch', ylabel='count'>

# %%
sns.countplot(df['test_preparation_course'])
# Out:
# C:\Users\Sanjana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='test_preparation_course', ylabel='count'>

# %%
df['Total Score']=df['math_score']+df['reading_score']+df['writing_score']

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df['AvgScore']=df['Total Score']/3

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score   AvgScore
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
plt.figure(figsize=(20,7))
plt.subplot(1,3,1)
sns.histplot(data=df,x="math_score",hue='gender',palette={'male': 'lightblue', 'female': 'pink'})
plt.subplot(1,3,2)
sns.histplot(data=df,x="reading_score",hue='gender',palette={'male': 'lightblue', 'female': 'pink'})
plt.subplot(1,3,3)
sns.histplot(data=df,x="writing_score",hue='gender',palette={'male': 'lightblue', 'female': 'pink'})
# Out:
# <AxesSubplot:xlabel='writing_score', ylabel='Count'>

# %%
sns.histplot(data=df,x='Total Score',hue='gender',palette={'male': 'lightblue', 'female': 'pink'})
# Out:
# <AxesSubplot:xlabel='Total Score', ylabel='Count'>

# %%
sns.histplot(data=df, x='AvgScore', hue='gender', palette={'male': 'lightblue', 'female': 'pink'})
# Out:
# <AxesSubplot:xlabel='AvgScore', ylabel='Count'>

# %%
sns.histplot(data=df,x="Total Score",hue="parental_level_of_education")
# Out:
# <AxesSubplot:xlabel='Total Score', ylabel='Count'>

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 3, 1)
sns.violinplot(data=df,y="math_score",color="pink")
plt.subplot(1, 3, 2)
sns.violinplot(data=df,y="reading_score",color="lemonchiffon")
plt.subplot(1, 3, 3)
sns.violinplot(data=df,y="writing_score",color="skyblue")
# Out:
# <AxesSubplot:ylabel='writing_score'>

# %%
sns.histplot(data=df,x="Total Score",hue="lunch")
# Out:
# <AxesSubplot:xlabel='Total Score', ylabel='Count'>

# %%
sns.barplot(data=df,y="Total Score",x="race_ethnicity",hue="gender",palette={'male': 'lightblue', 'female': 'pink'})
# Out:
# <AxesSubplot:xlabel='race_ethnicity', ylabel='Total Score'>

# %%
sns.barplot(data=df,y="AvgScore",x="race_ethnicity",hue="gender",palette={'male': 'lightblue', 'female': 'pink'})
# Out:
# <AxesSubplot:xlabel='race_ethnicity', ylabel='AvgScore'>

# %%
sns.histplot(data=df,x="Total Score",hue="test_preparation_course")
# Out:
# <AxesSubplot:xlabel='Total Score', ylabel='Count'>

# %%
sns.pairplot(df)
